# %% [markdown]
# # Product Recommendation System - Interactive Dashboard
#
# This notebook contains an interactive dashboard for simulating real-time product recommendations based on RFM (Recency, Frequency, Monetary) analysis.
#
# ## Features:
# - **RFM Score Adjustment**: Dynamically adjust customer RFM scores (1-5 scale)
# - **Raw Value Input**: Enter specific recency, frequency, and monetary values
# - **Real-time Prediction**: Get instant "Recommend / Do Not Recommend" decisions
# - **Visual Analysis**: See customer profile relative to the dataset
# - **Confidence Scores**: View prediction probabilities and confidence levels

# %%
# Import required libraries
import sys
sys.path.append('../src')

from dashboard import run_dashboard

# Run the interactive dashboard
run_dashboard()

# %% [markdown]
# ## How to Use:
#
# 1. **Adjust RFM Scores**: Use the sliders to set customer scores (1-5 scale)
#    - **Recency Score**: Higher = more recent purchases (better)
#    - **Frequency Score**: Higher = more frequent purchases (better)
#    - **Monetary Score**: Higher = higher spending (better)
#
# 2. **Or Enter Raw Values**: Input specific customer data
#    - **Recency**: Days since last purchase (lower = better)
#    - **Frequency**: Number of transactions (higher = better)
#    - **Monetary**: Total spending amount (higher = better)
#
# 3. **Click Predict**: Get recommendation and analysis
#
# 4. **Review Results**: See confidence scores and customer profile visualization

# %% [markdown]
# ## Model Performance:
# - **Accuracy**: 100% on test set (868 samples)
# - **Most Predictive Features**: Monetary (98.6%), Frequency Score (0.5%), Recency (0.4%)
# - **Dataset**: 4,339 customers with balanced high/low value split
